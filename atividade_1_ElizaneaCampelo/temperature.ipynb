# %%
# %pip install pandas
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# Carregar dados
file_path = 'C:\\Users\\eliz1\\Desktop\\cesarSschool2024\\SeriesTemporais\\atividade_1_ElizaneaCampelo\\temperature.txt'
data = pd.read_csv(file_path, header=None, names=['actual'])

# Visualizar os primeiros dados
print(data.head())
# Out:
#    actual
# 0    40.6
# 1    40.8
# 2    44.4
# 3    46.7
# 4    54.1

# %%
# Estatísticas descritivas
desc_stats = data.describe()
print(desc_stats)
# Out:
#            actual
# count  240.000000
# mean    49.041250
# std      8.569705
# min     31.300000
# 25%     41.550000
# 50%     47.350000
# 75%     57.000000
# max     66.500000

# %%
# Plotar a série temporal
plt.figure(figsize=(12, 6))
plt.plot(data['actual'], label='Actual')
plt.title('Time Series Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Plotar ACF e PACF
fig, ax = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(data['actual'], lags=40, ax=ax[0])
plot_pacf(data['actual'], lags=40, ax=ax[1])
plt.show()
# Out:
# c:\Users\eliz1\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Teste de Dickey-Fuller Aumentado
adf_result = adfuller(data['actual'])

# Resultados do teste ADF
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:', adf_result[4])
# Out:
# ADF Statistic: -3.255492403086339
# p-value: 0.01698903022260853
# Critical Values: {'1%': -3.4597521044060353, '5%': -2.874472927517147, '10%': -2.5736628197530864}
